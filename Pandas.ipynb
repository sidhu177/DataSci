# %%
import pandas as pd
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/sidhu177/DataSci/master/Demographic_Statistics_By_Zip_Code.csv'
    
Demo = pd.read_csv(url, sep = ',')

# %%
Demo.head(10)
# Out:
#    JURISDICTION NAME  COUNT PARTICIPANTS  COUNT FEMALE  PERCENT FEMALE  \
# 0              10001                  44            22            0.50
# 1              10002                  35            19            0.54
# 2              10003                   1             1            1.00
# 3              10004                   0             0            0.00
# 4              10005                   2             2            1.00
# 5              10006                   6             2            0.33
# 6              10007                   1             0            0.00
# 7              10009                   2             0            0.00
# 8              10010                   0             0            0.00
# 9              10011                   3             2            0.67
#
#    COUNT MALE  PERCENT MALE  COUNT GENDER UNKNOWN  PERCENT GENDER UNKNOWN  \
# 0          22          0.50                     0                       0
# ...

# %%
Demo.shape[0]
# Out:
# 236

# %%
Demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 46 columns):
# JURISDICTION NAME                      236 non-null int64
# COUNT PARTICIPANTS                     236 non-null int64
# COUNT FEMALE                           236 non-null int64
# PERCENT FEMALE                         236 non-null float64
# COUNT MALE                             236 non-null int64
# PERCENT MALE                           236 non-null float64
# COUNT GENDER UNKNOWN                   236 non-null int64
# PERCENT GENDER UNKNOWN                 236 non-null int64
# COUNT GENDER TOTAL                     236 non-null int64
# PERCENT GENDER TOTAL                   236 non-null int64
# COUNT PACIFIC ISLANDER                 236 non-null int64
# PERCENT PACIFIC ISLANDER               236 non-null float64
# COUNT HISPANIC LATINO                  236 non-null int64
# PERCENT HISPANIC LATINO                236 non-null float64
# ...

# %%
Demo.index
# Out:
# RangeIndex(start=0, stop=236, step=1)

# %%
c = Demo.groupby('JURISDICTION NAME')
c = c.sum()
c = c.sort_values(['COUNT FEMALE'], ascending=False)
c.head(10)
# Out:
#                    COUNT PARTICIPANTS  COUNT FEMALE  PERCENT FEMALE  \
# JURISDICTION NAME
# 11230                             248           194            0.78
# 12779                             242           183            0.76
# 11219                             214           182            0.85
# 12734                             252           170            0.67
# 12789                             272           115            0.42
# 11218                             111            97            0.87
# 12428                             124            74            0.60
# 12783                             201            66            0.33
# 10467                             106            65            0.61
# 12754                             134            64            0.48
#
#                    COUNT MALE  PERCENT MALE  COUNT GENDER UNKNOWN  \
# JURISDICTION NAME
# 11230                      54          0.22                     0
# ...

# %%
Demo.groupby(by=['COUNT PARTICIPANTS']).sum().mean()['COUNT FEMALE']
# Out:
# 45.849056603773583
